# %%
import pandas as pd
import os

# %% [markdown]
# # Import provided data

# %%
raw_data = pd.read_csv('/Users/timockenga/Programming/PD_Project/data/bremen.csv')
raw_data.head()
# Out:
#    Unnamed: 0  p_spot  p_place_type             datetime  b_number   trip  \
# 0           0    True             0  2019-01-20 02:06:00     11281  first
# 1           1    True             0  2019-01-20 14:16:00     11281   last
# 2           2    True             0  2019-01-20 00:00:00     11169  first
# 3           3    True             0  2019-01-20 01:55:00     11169  start
# 4           4    True             0  2019-01-20 02:06:00     11169    end
#
#      p_uid  p_bikes      p_lat  b_bike_type                          p_name  \
# 0  4774295        5  50.808852           15           Biegenstraße/Cineplex
# 1  4774295        4  50.808852           15           Biegenstraße/Cineplex
# 2  4774543        5  50.795224           15                      Südbahnhof
# 3  4774543        5  50.795224           15                      Südbahnhof
# 4  4774368        4  50.804522           15  Frankfurter Straße/Psychologie
#
#    p_number     p_lng  p_bike
# 0    5155.0  8.773134   False
# 1    5155.0  8.773134   False
# 2    5173.0  8.763266   False
# 3    5173.0  8.763266   False
# 4    5159.0  8.770358   False

# %%
raw_data.drop(columns=['Unnamed: 0'], inplace=True)

# %% [markdown]
# ## Check location data
#
# It is not only Bremen!

# %%
print(raw_data.p_lat.min())
print(raw_data.p_lat.max())
print(raw_data.p_lng.min())
print(raw_data.p_lng.max())
# Out:
# -504.153076
# 8084778.533
# -92.561901044101
# 20.973033333333

# %% [markdown]
# ## Check sum of null values

# %%
raw_data.isna().sum()
# Out:
# p_spot            0
# p_place_type      0
# datetime          0
# b_number          0
# trip              0
# p_uid             0
# p_bikes           0
# p_lat             0
# b_bike_type       0
# p_name            0
# p_number        181
# p_lng             0
# p_bike            0
# dtype: int64

# %% [markdown]
# # Get geodata of Bremen
#
# https://raw.githubusercontent.com/codeforamerica/click_that_hood/master/public/data/bremen.geojson

# %%
import folium

# %%
map_bremen = folium.Map(location=[53.122962,8.7515937], zoom_start=11)

folium.Choropleth(geo_data=F"/Users/timockenga/Programming/PD_Project/data/bremen.geojson").add_to(map_bremen)

map_bremen
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#map_bremen.save('map_bremen.html')

# %% [markdown]
# https://automating-gis-processes.github.io/CSC18/lessons/L4/point-in-polygon.html

# %%
from shapely.geometry import Point, Polygon

# %%
from shapely.ops import cascaded_union

# %%
import json

# %% [markdown]
# ## Save geodata in dictionary

# %%
district_polygons = {}

with open('/Users/timockenga/Programming/PD_Project/data/bremen.geojson') as f:
    data = json.load(f)

for feature in data['features']:
    
    district_name = (feature['properties']['name'])
    polygon = Polygon(feature['geometry']['coordinates'][0][0])
    
    district_polygons.update( {district_name : polygon})

# %%
print(len(district_polygons))
district_polygons
# Out:
# 88
# {'Blockland': <shapely.geometry.polygon.Polygon at 0x11ce420f0>,
#  'Ohlenhof': <shapely.geometry.polygon.Polygon at 0x11bb086a0>,
#  'Utbremen': <shapely.geometry.polygon.Polygon at 0x11bb086d8>,
#  'Neustadt': <shapely.geometry.polygon.Polygon at 0x11bb08710>,
#  'Neue Vahr Nord': <shapely.geometry.polygon.Polygon at 0x11bb08748>,
#  'Fähr-Lobbendorf': <shapely.geometry.polygon.Polygon at 0x11bb08780>,
#  'Grohn': <shapely.geometry.polygon.Polygon at 0x11bb087b8>,
#  'Rönnebeck': <shapely.geometry.polygon.Polygon at 0x11bb087f0>,
#  'Lindenhof': <shapely.geometry.polygon.Polygon at 0x11bb08828>,
#  'Gröpelingen': <shapely.geometry.polygon.Polygon at 0x11bb08860>,
#  'Oslebshausen': <shapely.geometry.polygon.Polygon at 0x11bb08898>,
#  'Weidedamm': <shapely.geometry.polygon.Polygon at 0x11bb088d0>,
#  'Ostertor': <shapely.geometry.polygon.Polygon at 0x11bb08908>,
#  'Ellener Feld': <shapely.geometry.polygon.Polygon at 0x11bb08940>,
#  'Schwachhausen': <shapely.geometry.polygon.Polygon at 0x11bb08978>,
#  'Rablinghausen': <shapely.geometry.polygon.Polygon at 0x11bb089b0>,
#  'Gartenstadt Süd': <shapely.geometry.polygon.Polygon at 0x11bb089e8>,
#  'Findorff-Bürgerweide': <shapely.geometry.polygon.Polygon at 0x11bb08a20>,
#  'Burg-Grambke': <shapely.geometry.polygon.Polygon at 0x11bb08a58>,
#  'Burgdamm': <shapely.geometry.polygon.Polygon at 0x11bb08a90>,
#  'Hulsberg': <shapely.geometry.polygon.Polygon at 0x11bb08ac8>,
#  'Lesum': <shapely.geometry.polygon.Polygon at 0x11bb08b00>,
#  'Vegesack': <shapely.geometry.polygon.Polygon at 0x11bb08b38>,
#  'Werderland': <shapely.geometry.polygon.Polygon at 0x11bb08b70>,
#  'St. Magnus': <shapely.geometry.polygon.Polygon at 0x11bb08ba8>,
#  'Aumund-Hammersbeck': <shapely.geometry.polygon.Polygon at 0x11bb08be0>,
#  'Schönebeck': <shapely.geometry.polygon.Polygon at 0x11bb08c18>,
#  'In den Wischen': <shapely.geometry.polygon.Polygon at 0x11bb08c50>,
#  'Blumenthal': <shapely.geometry.polygon.Polygon at 0x11bb08c88>,
#  'Überseestadt': <shapely.geometry.polygon.Polygon at 0x11bb08cc0>,
#  'Farge': <shapely.geometry.polygon.Polygon at 0x11bb08cf8>,
#  'Rekum': <shapely.geometry.polygon.Polygon at 0x11bb08d30>,
#  'Lüssum-Bockhorn': <shapely.geometry.polygon.Polygon at 0x11bb08d68>,
#  'Industriehäfen': <shapely.geometry.polygon.Polygon at 0x11bb08da0>,
#  'Regensburger Straße': <shapely.geometry.polygon.Polygon at 0x11bb08dd8>,
#  'In den Hufen': <shapely.geometry.polygon.Polygon at 0x11bb08e10>,
#  'Buntentor': <shapely.geometry.polygon.Polygon at 0x11bb08e48>,
#  'Altstadt': <shapely.geometry.polygon.Polygon at 0x11bb08e80>,
#  'Steintor': <shapely.geometry.polygon.Polygon at 0x11bb08eb8>,
#  'Borgfeld': <shapely.geometry.polygon.Polygon at 0x11bb08ef0>,
#  'Hohentorshafen': <shapely.geometry.polygon.Polygon at 0x11bb08f28>,
#  'Bahnhofsvorstadt': <shapely.geometry.polygon.Polygon at 0x11bb08f60>,
#  'Peterswerder': <shapely.geometry.polygon.Polygon at 0x11bb08f98>,
#  'Fesenfeld': <shapely.geometry.polygon.Polygon at 0x11bb08fd0>,
#  'Neue Vahr Südost': <shapely.geometry.polygon.Polygon at 0x11bb5b048>,
#  'Hemelingen': <shapely.geometry.polygon.Polygon at 0x11bb5b080>,
#  'Bürgerpark': <shapely.geometry.polygon.Polygon at 0x11bb5b0b8>,
#  'Hastedt': <shapely.geometry.polygon.Polygon at 0x11bb5b0f0>,
#  'Lehesterdeich': <shapely.geometry.polygon.Polygon at 0x11bb5b128>,
#  'Horn': <shapely.geometry.polygon.Polygon at 0x11bb5b160>,
#  'Arbergen': <shapely.geometry.polygon.Polygon at 0x11bb5b198>,
#  'Sebaldsbrück': <shapely.geometry.polygon.Polygon at 0x11bb5b1d0>,
#  'Mahndorf': <shapely.geometry.polygon.Polygon at 0x11bb5b208>,
#  'Lehe': <shapely.geometry.polygon.Polygon at 0x11bb5b240>,
#  'Tenever': <shapely.geometry.polygon.Polygon at 0x11bb5b278>,
#  'Blockdiek': <shapely.geometry.polygon.Polygon at 0x11bb5b2b0>,
#  'Ellenerbrok-Schevemoor': <shapely.geometry.polygon.Polygon at 0x11bb5b2e8>,
#  'Osterholz': <shapely.geometry.polygon.Polygon at 0x11bb5b320>,
#  'Neue Vahr Südwest': <shapely.geometry.polygon.Polygon at 0x11bb5b358>,
#  'Oberneuland': <shapely.geometry.polygon.Polygon at 0x11bb5b390>,
#  'Gartenstadt Vahr': <shapely.geometry.polygon.Polygon at 0x11bb5b3c8>,
#  'Radio Bremen': <shapely.geometry.polygon.Polygon at 0x11bb5b400>,
#  'Gete': <shapely.geometry.polygon.Polygon at 0x11bb5b438>,
#  'Barkhof': <shapely.geometry.polygon.Polygon at 0x11bb5b470>,
#  'Riensberg': <shapely.geometry.polygon.Polygon at 0x11bb5b4a8>,
#  'Neu-Schwachhausen': <shapely.geometry.polygon.Polygon at 0x11bb5b4e0>,
#  'Neustädter Häfen': <shapely.geometry.polygon.Polygon at 0x11bb5b518>,
#  'Woltmershausen': <shapely.geometry.polygon.Polygon at 0x11bb5b550>,
#  'Habenhausen': <shapely.geometry.polygon.Polygon at 0x11bb5b588>,
#  'Neuenland': <shapely.geometry.polygon.Polygon at 0x11bb5b5c0>,
#  'Hohentor': <shapely.geometry.polygon.Polygon at 0x11bb5b5f8>,
#  'Sodenmatt': <shapely.geometry.polygon.Polygon at 0x11bb5b630>,
#  'Strom': <shapely.geometry.polygon.Polygon at 0x11bb5b668>,
#  'Seehausen': <shapely.geometry.polygon.Polygon at 0x11bb5b6a0>,
#  'Südervorstadt': <shapely.geometry.polygon.Polygon at 0x11bb5b6d8>,
#  'Alte Neustadt': <shapely.geometry.polygon.Polygon at 0x11bb5b710>,
#  'Huckelriede': <shapely.geometry.polygon.Polygon at 0x11bb5b748>,
#  'Mittelshuchting': <shapely.geometry.polygon.Polygon at 0x11bb5b780>,
#  'Kirchhuchting': <shapely.geometry.polygon.Polygon at 0x11bb5b7b8>,
#  'Grolland': <shapely.geometry.polygon.Polygon at 0x11bb5b7f0>,
#  'Kattenesch': <shapely.geometry.polygon.Polygon at 0x11bb5b828>,
#  'Arsten': <shapely.geometry.polygon.Polygon at 0x11bb5b860>,
#  'Kattenturm': <shapely.geometry.polygon.Polygon at 0x11bb5b898>,
#  'Steffensweg': <shapely.geometry.polygon.Polygon at 0x11bb5b8d0>,
#  'Westend': <shapely.geometry.polygon.Polygon at 0x11bb5b908>,
#  'Walle': <shapely.geometry.polygon.Polygon at 0x11bb5b940>,
#  'Osterfeuerberg': <shapely.geometry.polygon.Polygon at 0x11bb5b978>,
#  'Hohweg': <shapely.geometry.polygon.Polygon at 0x11bb5b9b0>}

# %% [markdown]
# ## Functions get district of point or false if not in Bremen - not necessary at this point

# %%
def getDistrict(latitude, longitude, polygons):

    point = Point(longitude,latitude)
    
    for name, polygon in polygons.items():
        
        if point.within(polygon):
            return name
        
    return False

# %%
getDistrict(53.043962,8.9515937,district_polygons)
# Out:
# 'Osterholz'

# %% [markdown]
# ### Not necessary at all because getDistrict also determines if point is inside Bremens boundaries

# %%
def pointInBremen2(latitude, longitude, polygons):

    point = Point(longitude,latitude)
    
    bremen = cascaded_union(polygons.values())
    
    if point.within(bremen):
        return True
        
    return False

# %%
pointInBremen2(53.021037,8.491593,district_polygons)
# Out:
# False

# %% [markdown]
# ## Get boundaries (min & max values for latitude & longitude) of Bremen

# %%
cascaded_union(district_polygons.values()).bounds
# Out:
# (8.481593, 53.011037, 8.990582, 53.228967)

# %% [markdown]
# ## Filter raw data exclusively for data points in Bremens boundaries

# %%
bremen = raw_data[(raw_data['p_lat'] < 53.228967) &
         (raw_data['p_lat'] > 53.011037) &
         (raw_data['p_lng'] < 8.990582)  &
         (raw_data['p_lng'] > 8.481593)]

print(len(bremen))
# Out:
# 1309078

# %%
bremen
# Out:
#          p_spot  p_place_type             datetime  b_number   trip     p_uid  \
# 2241283   False            12  2019-01-20 00:00:00     20668  first  12097754
# 2241284   False            12  2019-01-20 01:33:00     20668   last  12097754
# 2241285   False            12  2019-01-20 00:00:00     20649  first  12096803
# 2241286    True             0  2019-01-20 23:59:00     20649   last   8322444
# 2241287   False            12  2019-01-20 00:00:00     20964  first  12007715
# ...         ...           ...                  ...       ...    ...       ...
# 3585586   False            12  2019-12-31 09:17:00     20905  start  26494106
# 3585587   False            12  2019-12-31 09:24:00     20905    end  26501789
# 3585588   False            12  2019-12-31 13:55:00     20905  start  26507153
# 3585589   False            12  2019-12-31 14:01:00     20905    end  26507979
# 3585590   False            12  2019-12-31 23:59:00     20905   last  26507979
#
#          p_bikes      p_lat  b_bike_type      p_name  p_number     p_lng  \
# 2241283        1  53.081698           71  BIKE 20668       0.0  8.812411
# 2241284        1  53.081767           71  BIKE 20668       0.0  8.812408
# 2241285        1  53.081533           71  BIKE 20649       0.0  8.790704
# 2241286        1  53.082464           71  WeserTower    2971.0  8.789556
# 2241287        1  53.100197           71  BIKE 20964       0.0  8.817565
# ...          ...        ...          ...         ...       ...       ...
# 3585586        1  53.088858           71  BIKE 20905       0.0  8.810082
# 3585587        1  53.080680           71  BIKE 20905       0.0  8.815383
# 3585588        1  53.080884           71  BIKE 20905       0.0  8.815197
# 3585589        1  53.082618           71  BIKE 20905       0.0  8.805761
# 3585590        1  53.082729           71  BIKE 20905       0.0  8.805467
#
#          p_bike
# 2241283    True
# 2241284    True
# 2241285    True
# 2241286   False
# 2241287    True
# ...         ...
# 3585586    True
# 3585587    True
# 3585588    True
# 3585589    True
# 3585590    True
#
# [1309078 rows x 13 columns]

# %%
bremen = bremen.reset_index().drop(columns=['index'])

# %% [markdown]
# # Add district to each row/booking

# %% [markdown]
# from tqdm import tqdm

# %% [markdown]
# i = 0
# for index, row in tqdm(bremen[bremen['district'] == 'Nicht bestimmt'].iterrows()):
#     bremen['district'].iloc[index] = getDistrict(row['p_lat'], row['p_lng'], district_polygons)
#     if i > 100000:
#         bremen.to_csv('bremen_data.csv')
#         i = 0
#     i+=1
# bremen.to_csv('bremen_data.csv', index=False)

# %% [markdown]
# ## Import data set with district

# %%
bremen = pd.read_csv('preprocessed_data.csv')

# %%
bremen.sample(2)
# Out:
#          p_spot  p_place_type             datetime  b_number trip     p_uid  \
# 703761     True             0  2019-02-14 09:40:00     20745  end  10278696
# 1266840   False            12  2019-12-05 18:31:00     20889  end  25679416
#
#          p_bikes      p_lat  b_bike_type                       p_name  \
# 703761         4  53.085032           71  GEWOBA | Wilh.-Liebknecht 1
# 1266840        1  53.072920           71                   BIKE 20889
#
#          p_number     p_lng  p_bike        district
# 703761     2987.0  8.879126   False  Neue Vahr Nord
# 1266840       0.0  8.826910    True        Steintor

# %%
len(bremen)
# Out:
# 1309078

# %% [markdown]
# # Order data frame usefully

# %%
bremen.keys()
# Out:
# Index(['p_spot', 'p_place_type', 'datetime', 'b_number', 'trip', 'p_uid',
#        'p_bikes', 'p_lat', 'b_bike_type', 'p_name', 'p_number', 'p_lng',
#        'p_bike', 'district'],
#       dtype='object')

# %%
bremen = bremen[['datetime', 'b_number', 'p_spot', 'p_place_type',
                 'trip', 'p_uid', 'p_bikes', 'b_bike_type', 'p_name',
                 'p_number', 'p_bike', 'p_lat', 'p_lng', 'district']]

#bremen.to_csv('bremen_data.csv', index=False)

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Total number of bookings

# %%
len(bremen)
# Out:
# 1309078

# %% [markdown]
# ## Total number of null values

# %%
bremen.isna().sum()
# Out:
# p_spot           0
# p_place_type     0
# datetime         0
# b_number         0
# trip             0
# p_uid            0
# p_bikes          0
# p_lat            0
# b_bike_type      0
# p_name           0
# p_number        88
# p_lng            0
# p_bike           0
# dtype: int64

# %% [markdown]
# ## Total number of bikes - 443

# %%
print(len(bremen.b_number.unique()))
print(bremen.b_number.unique()[:10])
# Out:
# 443
# [20668 20649 20964 20866 20799 20676 20855 20707 20815 20891]

# %% [markdown]
# ### For a specific bike check trips - seem to be many duplicates!

# %%
bremen[bremen.b_number == 20668].sort_values('datetime')[:20]
# Out:
#                    datetime  b_number  p_spot  p_place_type   trip     p_uid  \
# 0       2019-01-20 00:00:00     20668   False            12  first  12097754
# 654539  2019-01-20 00:00:00     20668   False            12  first  12097754
# 1       2019-01-20 01:33:00     20668   False            12   last  12097754
# 654540  2019-01-20 01:33:00     20668   False            12   last  12097754
# 1583    2019-01-22 09:15:00     20668    True             0  first   7873316
# 656122  2019-01-22 09:15:00     20668    True             0  first   7873316
# 1584    2019-01-22 09:42:00     20668    True             0  start   7873316
# 656123  2019-01-22 09:42:00     20668    True             0  start   7873316
# 1585    2019-01-22 09:49:00     20668   False            12    end  12155136
# 656124  2019-01-22 09:49:00     20668   False            12    end  12155136
# 1586    2019-01-22 14:52:00     20668   False            12  start  12155136
# 656125  2019-01-22 14:52:00     20668   False            12  start  12155136
# 1587    2019-01-22 15:35:00     20668   False            12    end  12162204
# 656126  2019-01-22 15:35:00     20668   False            12    end  12162204
# 656127  2019-01-22 23:59:00     20668   False            12   last  12162204
# 1588    2019-01-22 23:59:00     20668   False            12   last  12162204
# 657011  2019-01-23 00:00:00     20668   False            12  first  12162204
# 2472    2019-01-23 00:00:00     20668   False            12  first  12162204
# 657012  2019-01-23 10:42:00     20668   False            12   last  12162204
# 2473    2019-01-23 10:42:00     20668   False            12   last  12162204
#
#         p_bikes  b_bike_type                         p_name  p_number  p_bike  \
# 0             1           71                     BIKE 20668       0.0    True
# 654539        1           71                     BIKE 20668       0.0    True
# 1             1           71                     BIKE 20668       0.0    True
# 654540        1           71                     BIKE 20668       0.0    True
# 1583          5           71  Hauptbahnhof / Übersee Museum    2946.0   False
# 656122        5           71  Hauptbahnhof / Übersee Museum    2946.0   False
# 1584          5           71  Hauptbahnhof / Übersee Museum    2946.0   False
# 656123        5           71  Hauptbahnhof / Übersee Museum    2946.0   False
# 1585          1           71                     BIKE 20668       0.0    True
# 656124        1           71                     BIKE 20668       0.0    True
# 1586          1           71                     BIKE 20668       0.0    True
# 656125        1           71                     BIKE 20668       0.0    True
# 1587          1           71                     BIKE 20668       0.0    True
# 656126        1           71                     BIKE 20668       0.0    True
# 656127        1           71                     BIKE 20668       0.0    True
# 1588          1           71                     BIKE 20668       0.0    True
# 657011        1           71                     BIKE 20668       0.0    True
# 2472          1           71                     BIKE 20668       0.0    True
# 657012        1           71                     BIKE 20668       0.0    True
# 2473          1           71                     BIKE 20668       0.0    True
#
#             p_lat     p_lng          district
# 0       53.081698  8.812411  Bahnhofsvorstadt
# 654539  53.081698  8.812411  Bahnhofsvorstadt
# 1       53.081767  8.812408  Bahnhofsvorstadt
# 654540  53.081767  8.812408  Bahnhofsvorstadt
# 1583    53.083167  8.811472  Bahnhofsvorstadt
# 656122  53.083167  8.811472  Bahnhofsvorstadt
# 1584    53.083167  8.811472  Bahnhofsvorstadt
# 656123  53.083167  8.811472  Bahnhofsvorstadt
# 1585    53.080356  8.795718          Altstadt
# 656124  53.080356  8.795718          Altstadt
# 1586    53.080453  8.795549          Altstadt
# 656125  53.080453  8.795549          Altstadt
# 1587    53.062169  8.875182           Hastedt
# 656126  53.062169  8.875182           Hastedt
# 656127  53.061929  8.875118           Hastedt
# 1588    53.061929  8.875118           Hastedt
# 657011  53.061929  8.875118           Hastedt
# 2472    53.061929  8.875118           Hastedt
# 657012  53.062032  8.875321           Hastedt
# 2473    53.062032  8.875321           Hastedt

# %% [markdown]
# ## Check for duplicates

# %%
bremen.duplicated(subset=['datetime', 'b_number','trip']).sum()
# Out:
# 654539

# %%
bremen.duplicated(subset=None).sum()
# Out:
# 615607

# %%
654539 - 615607
# Out:
# 38932

# %% [markdown]
# # TODO check datetime & b_number duplicates against subset=None

# %% [markdown]
# ### Half of data are duplicates

# %%
654539*2
# Out:
# 1309078

# %% [markdown]
# # Drop duplicates

# %%
bremen = bremen[bremen.duplicated(subset=['datetime', 'b_number'], keep='first') == False]

# %%
len(bremen)
# Out:
# 654539

# %%
bremen.isna().sum()
# Out:
# p_spot           0
# p_place_type     0
# datetime         0
# b_number         0
# trip             0
# p_uid            0
# p_bikes          0
# p_lat            0
# b_bike_type      0
# p_name           0
# p_number        44
# p_lng            0
# p_bike           0
# dtype: int64

# %% [markdown]
# ## Specifications of trip - start/end point - first and last  do not refer to duplicates

# %%
bremen.trip.unique()
# Out:
# array(['first', 'last', 'start', 'end'], dtype=object)

# %%
len(bremen[(bremen.trip != 'first') & (bremen.trip != 'last')])
# Out:
# 462455

# %%
bremen[bremen.b_number == 20668].sort_values('datetime')[:20]

# %%
bremen['datetime'] = pd.to_datetime(bremen['datetime'])

# %%
bremen[(bremen.b_number == 20668) & ((bremen.trip == 'first') & (bremen.datetime.dt.hour != 0))].sort_values('datetime')
# Out:
#                   datetime  b_number  p_spot  p_place_type   trip     p_uid  \
# 1583   2019-01-22 09:15:00     20668    True             0  first   7873316
# 4960   2019-01-25 07:46:00     20668    True             0  first   7873007
# 22427  2019-02-11 13:24:00     20668    True             0  first   7873893
# 66599  2019-02-28 14:19:00     20668   False            12  first  13051288
# 67889  2019-03-01 16:45:00     20668   False            12  first  13075883
# 101708 2019-03-19 09:28:00     20668   False            12  first  13428348
# 109350 2019-03-25 10:56:00     20668    True             0  first   8638942
# 122190 2019-04-01 06:33:00     20668   False            12  first  13917223
# 192569 2019-04-30 08:29:00     20668    True             0  first   7873316
# 196247 2019-05-01 03:51:00     20668    True             0  first   7873316
# 199086 2019-05-03 01:21:00     20668   False            12  first  15279482
# 213268 2019-05-10 05:53:00     20668    True             0  first   7873316
# 221319 2019-05-14 05:44:00     20668   False            12  first  15719683
# 243505 2019-05-24 11:26:00     20668    True             0  first   8806578
# 246428 2019-05-25 02:26:00     20668   False            12  first  16231426
# 325742 2019-06-25 07:38:00     20668   False            12  first  17977555
# 333759 2019-06-29 11:36:00     20668    True             0  first   7873781
# 337618 2019-08-01 06:25:00     20668   False            12  first  19874152
# 457929 2019-09-19 16:19:00     20668    True             0  first  10278729
# 498155 2019-10-09 06:11:00     20668    True             0  first   7873316
# 505798 2019-10-13 10:17:00     20668   False            12  first  23349750
# 538780 2019-10-27 01:00:00     20668   False            12  first  24034886
# 633858 2019-12-18 08:36:00     20668    True             0  first   7873893
# 637331 2019-12-20 08:11:00     20668    True             0  first   7873316
# 642925 2019-12-24 09:25:00     20668    True             0  first   7873316
#
#         p_bikes  b_bike_type                                    p_name  \
# 1583          5           71             Hauptbahnhof / Übersee Museum
# 4960          4           71                                 Domsheide
# 22427         2           71                       Woltmershauser Str.
# 66599         1           71                                BIKE 20668
# 67889         1           71                                BIKE 20668
# 101708        1           71                                BIKE 20668
# 109350        4           71                             Föhrenstraße
# 122190        1           71                      Hamburger Straße 248
# 192569        5           71             Hauptbahnhof / Übersee Museum
# 196247        5           71             Hauptbahnhof / Übersee Museum
# 199086        1           71                                BIKE 20668
# 213268        5           71             Hauptbahnhof / Übersee Museum
# 221319        1           71                                BIKE 20668
# 243505        5           71                       GOP / Steigenberger
# 246428        1           71                                BIKE 20668
# 325742        1           71                                BIKE 20668
# 333759        4           71  Schwachhauser Heerstr. / Kirchbachstr.
# 337618        0           71                                BIKE 20668
# 457929        7           71                     GEWOBA | Heideplatz 1
# 498155        4           71             Hauptbahnhof / Übersee Museum
# 505798        1           71                                BIKE 20668
# 538780        1           71                                BIKE 20668
# 633858        6           71                       Woltmershauser Str.
# 637331       11           71             Hauptbahnhof / Übersee Museum
# 642925        1           71             Hauptbahnhof / Übersee Museum
#
#         p_number  p_bike      p_lat     p_lng           district
# 1583      2946.0   False  53.083167  8.811472   Bahnhofsvorstadt
# 4960      2933.0   False  53.074592  8.810182           Altstadt
# 22427     2966.0   False  53.078528  8.779167     Woltmershausen
# 66599        0.0    True  53.081902  8.810073   Bahnhofsvorstadt
# 67889        0.0    True  53.070702  8.830958           Steintor
# 101708       0.0    True  53.078944  8.848838               Gete
# 109350    2972.0   False  53.064904  8.879091            Hastedt
# 122190       0.0    True  53.068182  8.849903       Peterswerder
# 192569    2946.0   False  53.083167  8.811472   Bahnhofsvorstadt
# 196247    2946.0   False  53.083167  8.811472   Bahnhofsvorstadt
# 199086       0.0    True  53.082120  8.813189   Bahnhofsvorstadt
# 213268    2946.0   False  53.083167  8.811472   Bahnhofsvorstadt
# 221319       0.0    True  53.082236  8.786303       Überseestadt
# 243505    2977.0   False  53.082026  8.789213       Überseestadt
# 246428       0.0    True  53.096827  8.788237            Westend
# 325742       0.0    True  53.082382  8.817405            Barkhof
# 333759    2961.0   False  53.085000  8.849472               Gete
# 337618       0.0    True  53.082720  8.812902   Bahnhofsvorstadt
# 457929    2989.0   False  53.074731  8.876003   Gartenstadt Vahr
# 498155    2946.0   False  53.083167  8.811472   Bahnhofsvorstadt
# 505798       0.0    True  53.068311  8.790262           Neustadt
# 538780       0.0    True  53.079573  8.882023  Neue Vahr Südwest
# 633858    2966.0   False  53.078581  8.779235     Woltmershausen
# 637331    2946.0   False  53.083051  8.811647   Bahnhofsvorstadt
# 642925    2946.0   False  53.083051  8.811647   Bahnhofsvorstadt

# %% [markdown]
# ## Specifications of p_bikes - # of available bikes at position/station

# %%
bremen.p_bikes.unique()
# Out:
# array([ 1,  2,  3,  5,  4,  0,  7,  6,  8,  9, 11, 10, 12, 15, 14, 13, 16,
#        17, 31, 30, 32, 28, 20, 25, 26, 18, 23, 21, 27, 22, 29, 19])

# %%
bremen[bremen.p_spot == False].p_bikes.max()
# Out:
# 2

# %% [markdown]
# ## Specifications of b_bike_type - two different types of bikes?

# %%
bremen.b_bike_type.unique()
# Out:
# array([71, 29])

# %% [markdown]
# ## Specifications of p_bike - if True not in official area - opposite of p_spot

# %%
bremen.p_bike.unique()
# Out:
# array([ True, False])

# %% [markdown]
# ## Specifications of p_spot - is inside official station area - if True there is a p_name - opposite of p_bike

# %%
bremen.p_spot.unique()
# Out:
# array([False,  True])

# %% [markdown]
# ## Total number of p_uid - ids of official locations - related to p_name

# %%
len(bremen.p_uid.unique())
# Out:
# 157164

# %%
len(bremen[bremen.p_spot == True].p_uid.unique())
# Out:
# 76

# %%
for p_uid in bremen[bremen.p_spot == True].p_uid.unique():
    print(p_uid)
    print(bremen[bremen.p_uid == p_uid].district.unique())
# Out:
# 8322444
# ['Überseestadt' 'Woltmershausen']
# 7873706
# ['Woltmershausen']
# 10278716
# ['Neue Vahr Südost']
# 7872739
# ['Blumenthal']
# 2351602
# ['Altstadt']
# 7873007
# ['Altstadt']
# 8638942
# ['Hastedt']
# 7873840
# ['Lehe']
# 7873210
# ['Neustadt']
# 7873146
# ['Altstadt']
# 7873421
# ['Grohn']
# 11119973
# ['Überseestadt']
# 8806546
# ['Bürgerpark']
# 10278649
# ['Neue Vahr Südwest']
# 7872765
# ['Farge']
# 10084718
# ['Lehe']
# 8615035
# ['False']
# 7872789
# ['Mahndorf']
# 8322400
# ['Überseestadt']
# 7873118
# ['Gartenstadt Süd']
# 10278671
# ['Neue Vahr Nord']
# 7873316
# ['Bahnhofsvorstadt']
# 7873483
# ['Neustadt']
# 7873825
# ['Lehe']
# 8172362
# ['Altstadt']
# 8740854
# ['Kattenturm']
# 7873893
# ['Woltmershausen']
# 7873338
# ['Vegesack']
# 8028225
# ['Neuenland']
# 7873255
# ['False']
# 7873189
# ['Neu-Schwachhausen']
# 7873297
# ['Hastedt']
# 8903474
# ['False']
# 7873805
# ['Alte Neustadt']
# 7873781
# ['Gete']
# 8322336
# ['Altstadt']
# 10278696
# ['Neue Vahr Nord']
# 7873131
# ['Kattenturm']
# 7872920
# ['Sebaldsbrück']
# 7873874
# ['Bürgerpark']
# 7873026
# ['Weidedamm']
# 7873660
# ['Bahnhofsvorstadt']
# 7873436
# ['Habenhausen']
# 7873169
# ['Borgfeld']
# 7873233
# ['Huckelriede']
# 7873056
# ['Neuenland']
# 7873462
# ['Überseestadt']
# 7873621
# ['Alte Neustadt']
# 7872668
# ['Ostertor']
# 8926613
# ['Altstadt' 'Überseestadt']
# 7872979
# ['Überseestadt']
# 7872954
# ['Neue Vahr Südost']
# 7872701
# ['Überseestadt']
# 7873367
# ['Steintor']
# 7873274
# ['Westend']
# 10551452
# ['Lehe']
# 7873641
# ['Oberneuland']
# 7873594
# ['Oberneuland']
# 10278804
# ['Walle']
# 12732840
# ['Arsten']
# 12886693
# ['Bahnhofsvorstadt' 'Findorff-Bürgerweide']
# 8806578
# ['Überseestadt']
# 13019673
# ['Findorff-Bürgerweide']
# 8638975
# ['Ostertor']
# 7873766
# ['Weidedamm' 'Alte Neustadt']
# 8638959
# ['Findorff-Bürgerweide']
# 8322249
# ['Peterswerder']
# 10278729
# ['Gartenstadt Vahr']
# 14879993
# ['Findorff-Bürgerweide' 'Rablinghausen' 'Huckelriede' 'Neu-Schwachhausen']
# 15098720
# ['Neu-Schwachhausen']
# 15859125
# ['Borgfeld' 'Westend']
# 15767205
# ['Walle']
# 16521413
# ['Neuenland']
# 17322858
# ['Hohweg' 'Überseestadt']
# 17322791
# ['In den Wischen' 'Lehe']
# 17322575
# ['Hohweg' 'Überseestadt']

# %% [markdown]
# # TODO check with station data set

# %% [markdown]
# ## Specifications of p_name

# %%
bremen.p_name.nunique()
# Out:
# 5975

# %%
bremen[bremen.p_name.str[:4] != 'BIKE'].p_name.unique()
# Out:
# array(['WeserTower', 'Pusdorfer Marktplatz', 'GEWOBA | Ludwig-Beck 2a',
#        ..., ' Faulenstraße 65', '53.082872, 8.812058',
#        'recording_91000056'], dtype=object)

# %% [markdown]
# # TODO fix names

# %% [markdown]
# ## Total number of district - there are officially 88

# %%
len(bremen.district.unique())
# Out:
# 87

# %% [markdown]
# ## Total number of p_number - stationIds numbers

# %%
print(len(bremen.p_number.unique()))
print(bremen.p_number.unique())
# Out:
# 80
# [    0.  2971.  2959.  2988.  2927.  2910.  2933.  2972.  2912.  2941.
#   2938.  2949.  2913.  2976.  2985.  2928. 29860.  2953.  2929.  2970.
#   2936.  2986.  2946.  2952.  2963.  2967.  2975.  2966.  2947.  2958.
#   2943.  2940.  2945.  2978.  2962.  2961.  2969.  2987.  2937.  2930.
#   2965.  2934.  2957.  2950.  2939.  2942.  2911.  2951.  2955.  2925.
#   2990.  2932.  2931.  2926.  2948.  2944.  2992.  2956.  2954.  2991.
#   2935.  2914.  2997.  2977.  2964.  2974.  2960.  2973.  2968.  2989.
#   2915.    nan  2916.  2917.  2919.  2918.  2920.  2923.  2922.  2921.]

# %% [markdown]
# ### For each p_number check all related districts

# %%
for p_number in bremen.p_number.unique():
    print(p_number)
    print(bremen[bremen.p_number == p_number].district.unique())
# Out:
# 0.0
# ['Bahnhofsvorstadt' 'Altstadt' 'Weidedamm' 'Lehe' 'Gartenstadt Süd'
#  'Neustadt' 'Peterswerder' 'Gete' 'Südervorstadt' 'Fesenfeld' 'Steintor'
#  'Neue Vahr Südwest' 'Neue Vahr Nord' 'Bürgerpark' 'Findorff-Bürgerweide'
#  'Sebaldsbrück' 'Buntentor' 'Hohentor' 'Alte Neustadt' 'Kattenturm'
#  'Barkhof' 'Riensberg' 'Radio Bremen' 'Überseestadt' 'Ostertor'
#  'Schwachhausen' 'Hastedt' 'Gartenstadt Vahr' 'Hohentorshafen'
#  'Regensburger Straße' 'Huckelriede' 'Steffensweg' 'Neu-Schwachhausen'
#  'Neue Vahr Südost' 'Horn' 'Oberneuland' 'Woltmershausen' 'Hulsberg'
#  'Hemelingen' 'False' 'Neuenland' 'Utbremen' 'Vegesack' 'Blumenthal'
#  'Grohn' 'Westend' 'Hohweg' 'Farge' 'Walle' 'Lehesterdeich' 'Habenhausen'
#  'Schönebeck' 'In den Hufen' 'Industriehäfen' 'Grolland' 'Osterfeuerberg'
#  'Borgfeld' 'St. Magnus' 'Rablinghausen' 'Ellenerbrok-Schevemoor'
#  'Blockland' 'Blockdiek' 'Burg-Grambke' 'Kirchhuchting' 'Lesum'
#  'Osterholz' 'Arsten' 'Sodenmatt' 'Tenever' 'Gröpelingen' 'Lindenhof'
#  'Kattenesch' 'Arbergen' 'Ellener Feld' 'Rönnebeck' 'Rekum' 'Oslebshausen'
#  'Ohlenhof' 'Neustädter Häfen' 'Mittelshuchting' 'Fähr-Lobbendorf'
#  'Mahndorf' 'Burgdamm' 'In den Wischen' 'Strom' 'Werderland' 'Seehausen']
# 2971.0
# ['Überseestadt' 'Woltmershausen']
# 2959.0
# ['Woltmershausen']
# 2988.0
# ['Neue Vahr Südost']
# 2927.0
# ['Blumenthal']
# 2910.0
# ['Altstadt']
# 2933.0
# ['Altstadt']
# 2972.0
# ['Hastedt']
# 2912.0
# ['Lehe']
# 2941.0
# ['Neustadt']
# 2938.0
# ['Altstadt']
# 2949.0
# ['Grohn']
# 2913.0
# ['Überseestadt']
# 2976.0
# ['Bürgerpark']
# 2985.0
# ['Neue Vahr Südwest']
# 2928.0
# ['Farge']
# 29860.0
# ['Lehe']
# 2953.0
# ['False']
# 2929.0
# ['Mahndorf']
# 2970.0
# ['Überseestadt']
# 2936.0
# ['Gartenstadt Süd']
# 2986.0
# ['Neue Vahr Nord']
# 2946.0
# ['Bahnhofsvorstadt']
# 2952.0
# ['Neustadt']
# 2963.0
# ['Lehe']
# 2967.0
# ['Altstadt']
# 2975.0
# ['Kattenturm']
# 2966.0
# ['Woltmershausen']
# 2947.0
# ['Vegesack']
# 2958.0
# ['Neuenland']
# 2943.0
# ['False']
# 2940.0
# ['Neu-Schwachhausen']
# 2945.0
# ['Hastedt']
# 2978.0
# ['False']
# 2962.0
# ['Alte Neustadt']
# 2961.0
# ['Gete']
# 2969.0
# ['Altstadt']
# 2987.0
# ['Neue Vahr Nord']
# 2937.0
# ['Kattenturm']
# 2930.0
# ['Sebaldsbrück']
# 2965.0
# ['Bürgerpark']
# 2934.0
# ['Weidedamm']
# 2957.0
# ['Bahnhofsvorstadt']
# 2950.0
# ['Habenhausen']
# 2939.0
# ['Borgfeld']
# 2942.0
# ['Huckelriede']
# 2911.0
# ['Neuenland']
# 2951.0
# ['Überseestadt']
# 2955.0
# ['Alte Neustadt']
# 2925.0
# ['Ostertor']
# 2990.0
# ['Altstadt' 'Überseestadt']
# 2932.0
# ['Überseestadt']
# 2931.0
# ['Neue Vahr Südost']
# 2926.0
# ['Überseestadt']
# 2948.0
# ['Steintor']
# 2944.0
# ['Westend']
# 2992.0
# ['Lehe']
# 2956.0
# ['Oberneuland']
# 2954.0
# ['Oberneuland']
# 2991.0
# ['Walle']
# 2935.0
# ['Arsten']
# 2914.0
# ['Bahnhofsvorstadt' 'Findorff-Bürgerweide']
# 2997.0
# ['Lehe']
# 2977.0
# ['Überseestadt']
# 2964.0
# ['Findorff-Bürgerweide']
# 2974.0
# ['Ostertor']
# 2960.0
# ['Weidedamm' 'Alte Neustadt']
# 2973.0
# ['Findorff-Bürgerweide']
# 2968.0
# ['Peterswerder']
# 2989.0
# ['Gartenstadt Vahr']
# 2915.0
# ['Findorff-Bürgerweide' 'Rablinghausen' 'Huckelriede' 'Neu-Schwachhausen']
# nan
# []
# 2916.0
# ['Neu-Schwachhausen']
# 2917.0
# ['Lehe' 'Neuenland']
# 2919.0
# ['Borgfeld' 'Westend']
# 2918.0
# ['Walle']
# 2920.0
# ['Neuenland']
# 2923.0
# ['Hohweg' 'Überseestadt']
# 2922.0
# ['In den Wischen' 'Lehe']
# 2921.0
# ['Hohweg' 'Überseestadt']

# %% [markdown]
# ### Conclusion:
#
# p_number: station_id, p_uid: nextBike districts?

# %% [markdown]
# # Plot some data points
#
# Check if possible that if too many points only one cluster point displayed

# %%
from folium.plugins import MarkerCluster, FastMarkerCluster

# %%
from tqdm import tqdm

# %%
def plotDataPoints(latitudes, longitudes, color, fill_color, zoom):
    
    # Create map centered at Bremens center
    m = folium.Map(location=[53.122962,8.7515937], zoom_start=zoom)
    
    marker_cluster = MarkerCluster().add_to(m)
    #marker_cluster = FastMarkerCluster(data=list(zip(latitudes, longitudes))).add_to(m)
        
    if len(latitudes) != len(longitudes):
        print('latitudes & longitudes must be the same size!')
        
    info = 'No information available'
    
    for i in tqdm(range(len(latitudes))):
        
        folium.Circle(
            location=[latitudes[i],longitudes[i]],
            popup=folium.Popup(info, max_width = 450),
            radius=15,
            color=color,
            fill=True,
            fill_color=fill_color
        ).add_to(marker_cluster)
                  
    return m

# %%
plotDataPoints(bremen['p_lat'][:1500], bremen['p_lng'][:1500], color='royalblue', fill_color='indianred', zoom=11)
#.save('bremen_clustered.html')
# Out:
# 100%|██████████| 1500/1500 [00:00<00:00, 4890.25it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.GeoJson(F"/Users/timockenga/Downloads/map.geojson").add_to(map_bremen)

map_bremen
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# https://www.wk-bike.de/de/bremen/standorte/

# %% [markdown]
# https://gbfs.nextbike.net/maps/gbfs/v1/nextbike_wk/de/station_information.json
